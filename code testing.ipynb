# %%
import pandas as pd

# %%
df = pd.read_excel('Restaurant_1.xlsx')

# %%
dfnew = pd.concat([df]*3)

# %%
dfnew.head(15)
# Out:
#     Unnamed: 0           restaurant_id         restaurant_name price  rating  \
# 0            0  ehUuSk5gPTCQmwS_ubgKRA                 Upstate    $$     4.5
# 1            1  ETgJqJHV7BW6pIr9Ox74sA                  Amélie    $$     4.5
# 2            2  jjJc_CrkB2HodEinB6cWww                LoveMama    $$     4.5
# 3            3  C2o3Iw-DXjoUJFgQIbiqkQ                 BoCaphe    $$     4.0
# 4            4  CwOAKJdX8AMz5iAoA-ZEuA            Uglyduckling    $$     4.0
# 5            5  0CjK3esfpFcxIopebzjFxA          Joe's Shanghai    $$     4.0
# 6            6  UA2M9QFZghe-9th2KwLoWQ        Burger & Lobster    $$     4.0
# 7            7  s3jou_L_LVYGkNHiuhjlew  Boucherie West Village   $$$     4.5
# 8            8  VvsZAnEwU4c8Xkyrzx05Nw                 Anytime    $$     4.5
# 9            9  I2lgw_7DUnwD92ND4PN-Ow             Aunt Jake's    $$     4.0
# 10          10  B3_K2kUVbYOU0VaLcj_LTw              Thai Villa    $$     4.5
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       rating  review_count
# count  1000.000000  1000.000000   1000.000000
# mean    499.500000     4.174500    728.774000
# std     288.819436     0.307236    950.614108
# min       0.000000     3.000000      4.000000
# 25%     249.750000     4.000000    191.750000
# 50%     499.500000     4.000000    444.000000
# 75%     749.250000     4.500000    923.250000
# max     999.000000     5.000000  11706.000000

# %%
dfnew.describe()
# Out:
#         Unnamed: 0       rating  review_count
# count  3000.000000  3000.000000   3000.000000
# mean    499.500000     4.174500    728.774000
# std     288.723115     0.307134    950.297078
# min       0.000000     3.000000      4.000000
# 25%     249.750000     4.000000    191.750000
# 50%     499.500000     4.000000    444.000000
# 75%     749.250000     4.500000    923.250000
# max     999.000000     5.000000  11706.000000

# %%
dfnew.sort_index(axis=0)
# Out:
#      Unnamed: 0           restaurant_id            restaurant_name price  \
# 0             0  ehUuSk5gPTCQmwS_ubgKRA                    Upstate    $$
# 0             0  ehUuSk5gPTCQmwS_ubgKRA                    Upstate    $$
# 0             0  ehUuSk5gPTCQmwS_ubgKRA                    Upstate    $$
# 1             1  ETgJqJHV7BW6pIr9Ox74sA                     Amélie    $$
# 1             1  ETgJqJHV7BW6pIr9Ox74sA                     Amélie    $$
# 1             1  ETgJqJHV7BW6pIr9Ox74sA                     Amélie    $$
# 2             2  jjJc_CrkB2HodEinB6cWww                   LoveMama    $$
# 2             2  jjJc_CrkB2HodEinB6cWww                   LoveMama    $$
# 2             2  jjJc_CrkB2HodEinB6cWww                   LoveMama    $$
# 3             3  C2o3Iw-DXjoUJFgQIbiqkQ                    BoCaphe    $$
# 3             3  C2o3Iw-DXjoUJFgQIbiqkQ                    BoCaphe    $$
# 3             3  C2o3Iw-DXjoUJFgQIbiqkQ                    BoCaphe    $$
# ...

# %%
dfnew.drop(columns='Unnamed: 0')
# Out:
#               restaurant_id                restaurant_name price  rating  \
# 0    ehUuSk5gPTCQmwS_ubgKRA                        Upstate    $$     4.5
# 1    ETgJqJHV7BW6pIr9Ox74sA                         Amélie    $$     4.5
# 2    jjJc_CrkB2HodEinB6cWww                       LoveMama    $$     4.5
# 3    C2o3Iw-DXjoUJFgQIbiqkQ                        BoCaphe    $$     4.0
# 4    CwOAKJdX8AMz5iAoA-ZEuA                   Uglyduckling    $$     4.0
# 5    0CjK3esfpFcxIopebzjFxA                 Joe's Shanghai    $$     4.0
# 6    UA2M9QFZghe-9th2KwLoWQ               Burger & Lobster    $$     4.0
# 7    s3jou_L_LVYGkNHiuhjlew         Boucherie West Village   $$$     4.5
# 8    VvsZAnEwU4c8Xkyrzx05Nw                        Anytime    $$     4.5
# 9    I2lgw_7DUnwD92ND4PN-Ow                    Aunt Jake's    $$     4.0
# 10   B3_K2kUVbYOU0VaLcj_LTw                     Thai Villa    $$     4.5
# 11   ysqgdbSrezXgVwER2kQWKA                Juliana's Pizza    $$     4.5
# ...

# %%
dfnew.head()
# Out:
#    Unnamed: 0           restaurant_id restaurant_name price  rating  \
# 0           0  ehUuSk5gPTCQmwS_ubgKRA         Upstate    $$     4.5
# 1           1  ETgJqJHV7BW6pIr9Ox74sA          Amélie    $$     4.5
# 2           2  jjJc_CrkB2HodEinB6cWww        LoveMama    $$     4.5
# 3           3  C2o3Iw-DXjoUJFgQIbiqkQ         BoCaphe    $$     4.0
# 4           4  CwOAKJdX8AMz5iAoA-ZEuA    Uglyduckling    $$     4.0
#
#    review_count
# 0          1784
# 1          2565
# 2          4570
# 3          1288
# 4           458

# %%
dfnew.sort_index(axis=0, inplace=True)

# %%
dfnew.head(20)
# Out:
#    Unnamed: 0           restaurant_id   restaurant_name price  rating  \
# 0           0  ehUuSk5gPTCQmwS_ubgKRA           Upstate    $$     4.5
# 0           0  ehUuSk5gPTCQmwS_ubgKRA           Upstate    $$     4.5
# 0           0  ehUuSk5gPTCQmwS_ubgKRA           Upstate    $$     4.5
# 1           1  ETgJqJHV7BW6pIr9Ox74sA            Amélie    $$     4.5
# 1           1  ETgJqJHV7BW6pIr9Ox74sA            Amélie    $$     4.5
# 1           1  ETgJqJHV7BW6pIr9Ox74sA            Amélie    $$     4.5
# 2           2  jjJc_CrkB2HodEinB6cWww          LoveMama    $$     4.5
# 2           2  jjJc_CrkB2HodEinB6cWww          LoveMama    $$     4.5
# 2           2  jjJc_CrkB2HodEinB6cWww          LoveMama    $$     4.5
# 3           3  C2o3Iw-DXjoUJFgQIbiqkQ           BoCaphe    $$     4.0
# 3           3  C2o3Iw-DXjoUJFgQIbiqkQ           BoCaphe    $$     4.0
# 3           3  C2o3Iw-DXjoUJFgQIbiqkQ           BoCaphe    $$     4.0
# ...
